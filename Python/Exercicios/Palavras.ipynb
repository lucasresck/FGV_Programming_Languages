# %%
import string

# %%
text = input()
words = {word.lower().strip(string.punctuation):text.count(word) for word in text.split()}
PossibleNouns = [word for word in word if word.istitle and word]
# Out:
# Stack Overflow  Search…   Log In Sign Up This site uses cookies to deliver our services and to show you relevant ads and job listings. By using our site, you acknowledge that you have read and understand our Cookie Policy, Privacy Policy, and our Terms of Service. Your use of Stack Overflow’s Products and Services, including the Stack Overflow Network, is subject to these policies and terms.  Join us in building a kind, collaborative learning community via our updated Code of Conduct. Join Stack Overflow to learn, share knowledge, and build your career.  Email Sign Up OR SIGN IN WITH  Google  Facebook Home PUBLIC Stack Overflow Tags Users Jobs TEAMS Create Team  sort dict by value python Ask Question up vote 68 down vote favorite 28 Assume that I have a dict.  data = {1:'b', 2:'a'} And I want to sort data by 'b' and 'a' so I get the result  'a','b' How do I do that? Any ideas?  python dictionary python-2.6 shareimprove this question edited May 27 '13 at 12:42  jamylak 78k17171191 asked May 27 '13 at 11:22  kingRauk 4981619 5 possible duplicate of python dictionary values sorting – Ashwini Chaudhary May 27 '13 at 11:23  possible duplicate of How to sort dictionaries by keys in Python – njzk2 May 27 '13 at 12:31 2 possible duplicate of stackoverflow.com/questions/613183/… Give a look to this: stackoverflow.com/questions/613183/… – jimifiki May 27 '13 at 12:43 possible duplicate of How to sort a Python dict by value – nawfal Nov 11 '13 at 14:26 And what if I want a list of keys sorted by value? So the original would return [2, 1], could be a list of players sorted by their scores for example, discarding the scores. – gseattle Jul 17 '15 at 3:49  show 1 more comment 9 Answers active oldest votes up vote 147 down vote To get the values use  sorted(data.values()) To get the matching keys, use a key function  sorted(data, key=data.get) To get a list of tuples ordered by value  sorted(data.items(), key=lambda x:x[1]) Related: see the discussion here: Dictionaries are ordered in Python 3.6+  shareimprove this answer edited Aug 8 '17 at 20:32 answered May 27 '13 at 11:23  John La Rooy 200k36260413 Ok, sorry. What I meant was to get (2:'a',1:'b')... any ideas? – kingRauk May 27 '13 at 12:18 1 @kingRauk, dict's are unordered, but you can make an ordered list of tuples – John La Rooy May 27 '13 at 12:54 1 sorted(data.items(), key=lambda x:x[1], reverse=True) for reveresed order – Mannu Mar 5 at 8:33 add a comment  up vote 31 down vote If you actually want to sort the dictionary instead of just obtaining a sorted list use collections.OrderedDict  >>> from collections import OrderedDict >>> from operator import itemgetter >>> data = {1: 'b', 2: 'a'} >>> d = OrderedDict(sorted(data.items(), key=itemgetter(1))) >>> d OrderedDict([(2, 'a'), (1, 'b')]) >>> d.values() ['a', 'b'] shareimprove this answer answered May 27 '13 at 11:53  jamylak 78k17171191 The sad thing is that is in Python 2.6.5... that does not support OrderedDict – kingRauk May 27 '13 at 12:40 5 @kingRauk then don't tag your question Python 2.7.... Also a lot of things you have mentioned in the comments should have been in your question to begin with – jamylak May 27 '13 at 12:41  Yeah, sorry for that... – kingRauk May 27 '13 at 12:53 @kingRauk No problem at all, it's all good – jamylak May 19 '15 at 12:32  add a comment up vote 15 down vote From your comment to gnibbler answer, i'd say you want a list of pairs of key-value sorted by value:  sorted(data.items(), key=lambda x:x[1]) shareimprove this answer answered May 27 '13 at 12:35  njzk2 31.7k44987 add a comment up vote 7 down vote Sort the values:  sorted(data.values()) returns  ['a','b'] shareimprove this answer answered May 27 '13 at 11:23  eumiro 119k14210224 add a comment up vote 7 down vote Thanks for all answers. You are all my heros ;-)  Did in the end something like this:  d = sorted(data, key = d.get)  for id in d:     text = data[id] shareimprove this answer answered May 27 '13 at 13:01  kingRauk 4981619 add a commen ...

# %%
char = "."
char.
# Out:
# True
